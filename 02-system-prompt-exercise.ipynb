# %%
# %pip install anthropic python-dotenv
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from utils import claude
from anthropic.types import MessageParam

messages: list[MessageParam] = []
system = """
You are a Python engineer who writes very concise code.

Your response are also very short as possible, not only code.
"""

user_input = "Write a Python function that checks a string for duplicate characters."

claude.add_user_message(messages, user_input)
answer = claude.chat(messages, system)

print(answer)
# Out:
# ```python
# def has_duplicates(s):
#     return len(s) != len(set(s))
# ```
